# %%
import pandas as pd

# %%
data_cause = pd.read_csv("cause_of_deaths.csv", sep=",")

# %%
data_w_pop = pd.read_csv("World-population-by-countries-dataset.csv", sep=",")

# %%
data_cause.head(3)
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
#
#    Diabetes Mellitus  Chronic Kidney Disease  Poisonings  \
# 0               2108                    3709         338
# 1               2120                    3724         351
# ...

# %%
data_w_pop.head(3)
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54208.0      55434.0
# 1  Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                  Afghanistan          AFG    8996967.0    9169406.0
#
#           1962         1963         1964         1965         1966  \
# 0      56234.0      56699.0      57029.0      57357.0      57702.0
# 1  137614644.0  141202036.0  144920186.0  148769974.0  152752671.0
# 2    9351442.0    9543200.0    9744772.0    9956318.0   10174840.0
#
#           1967  ...         2012         2013         2014         2015  \
# 0      58044.0  ...     102565.0     103165.0     103776.0     104339.0
# 1  156876454.0  ...  547482863.0  562601578.0  578075373.0  593871847.0
# 2   10399936.0  ...   31161378.0   32269592.0   33370804.0   34413603.0
#
#           2016         2017         2018         2019         2020  \
# ...

# %%
dataset_final = data_cause.copy()

# %%
dataset_final["Population"] = 0

# %%
dataset_final.head(3)
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
#
#    Chronic Kidney Disease  Poisonings  Protein-Energy Malnutrition  \
# 0                    3709         338                         2054
# 1                    3724         351                         2119
# ...

# %%
dataset_final.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis', 'Population'],
#       dtype='object')

# %%
dataset_final = dataset_final[['Country/Territory', 'Code', 'Year', 'Population', 'Meningitis',
       "Alzheimer's Disease and Other Dementias", "Parkinson's Disease",
       'Nutritional Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']]

# %%
dataset_final.head(3)
# Out:
#   Country/Territory Code  Year  Population  Meningitis  \
# 0       Afghanistan  AFG  1990           0        2159
# 1       Afghanistan  AFG  1991           0        2218
# 2       Afghanistan  AFG  1992           0        2475
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
#
#    Nutritional Deficiencies  Malaria  Drowning  ...  Diabetes Mellitus  \
# 0                      2087       93      1370  ...               2108
# 1                      2153      189      1391  ...               2120
# 2                      2441      239      1514  ...               2153
#
#    Chronic Kidney Disease  Poisonings  Protein-Energy Malnutrition  \
# 0                    3709         338                         2054
# ...

# %%
for idx in data_cause.index:
    year = data_cause.iloc[idx, 2]
    code = data_cause.iloc[idx, 1]
    tmp = data_w_pop[[str(year), "Country Code"]][data_w_pop["Country Code"] == code]
    tmp = tmp.reset_index(drop=True)
    if tmp.shape[0] == 0:
        print(idx, " => code = ", code, " , year = ", year, " shape tmp = ", tmp.shape)
    else:
        dataset_final.iloc[idx, 3] = tmp.iloc[0,0]
# Out:
# 1230  => code =  COK  , year =  1990  shape tmp =  (0, 2)
# 1231  => code =  COK  , year =  1991  shape tmp =  (0, 2)
# 1232  => code =  COK  , year =  1992  shape tmp =  (0, 2)
# 1233  => code =  COK  , year =  1993  shape tmp =  (0, 2)
# 1234  => code =  COK  , year =  1994  shape tmp =  (0, 2)
# 1235  => code =  COK  , year =  1995  shape tmp =  (0, 2)
# 1236  => code =  COK  , year =  1996  shape tmp =  (0, 2)
# 1237  => code =  COK  , year =  1997  shape tmp =  (0, 2)
# 1238  => code =  COK  , year =  1998  shape tmp =  (0, 2)
# 1239  => code =  COK  , year =  1999  shape tmp =  (0, 2)
# 1240  => code =  COK  , year =  2000  shape tmp =  (0, 2)
# 1241  => code =  COK  , year =  2001  shape tmp =  (0, 2)
# 1242  => code =  COK  , year =  2002  shape tmp =  (0, 2)
# 1243  => code =  COK  , year =  2003  shape tmp =  (0, 2)
# 1244  => code =  COK  , year =  2004  shape tmp =  (0, 2)
# 1245  => code =  COK  , year =  2005  shape tmp =  (0, 2)
# ...

# %%
dataset_final.drop(dataset_final[dataset_final["Population"] == 0].index, inplace=True)

# %%
dataset_final.to_csv("cause_of_deaths_with_population.csv", sep=",", index=False)

# %%
dataset_final
# Out:
#      Country/Territory Code  Year  Population  Meningitis  \
# 0          Afghanistan  AFG  1990  12412311.0        2159
# 1          Afghanistan  AFG  1991  13299016.0        2218
# 2          Afghanistan  AFG  1992  14485543.0        2475
# 3          Afghanistan  AFG  1993  15816601.0        2812
# 4          Afghanistan  AFG  1994  17075728.0        3027
# ...                ...  ...   ...         ...         ...
# 6115          Zimbabwe  ZWE  2015  13814642.0        1439
# 6116          Zimbabwe  ZWE  2016  14030338.0        1457
# 6117          Zimbabwe  ZWE  2017  14236599.0        1460
# 6118          Zimbabwe  ZWE  2018  14438812.0        1450
# 6119          Zimbabwe  ZWE  2019  14645473.0        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# ...
